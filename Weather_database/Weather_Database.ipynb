# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90, size=2000)
lngs = np.random.uniform(-180,180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 763

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]     
        city_descrip = city_weather["weather"][0]["description"]     
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_descrip})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ribeira grande
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | mahebourg
# Processing Record 5 of Set 1 | provideniya
# Processing Record 6 of Set 1 | barra do corda
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | shingu
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | cherskiy
# Processing Record 13 of Set 1 | tikapur
# Processing Record 14 of Set 1 | kalmunai
# Processing Record 15 of Set 1 | hauterive
# Processing Record 16 of Set 1 | acapetahua
# Processing Record 17 of Set 1 | nizwa
# Processing Record 18 of Set 1 | nanortalik
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | torbay
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | kostomuksha
# Processing Record 26 of Set 1 | manama
# Processing Record 27 of Set 1 | hasaki
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 1 | quarai
# Processing Record 31 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 1 | vostok
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | hobyo
# Processing Record 35 of Set 1 | shu
# Processing Record 36 of Set 1 | dwarka
# Processing Record 37 of Set 1 | cap-aux-meules
# Processing Record 38 of Set 1 | stoyba
# City not found. Skipping...
# Processing Record 39 of Set 1 | flinders
# Processing Record 40 of Set 1 | tuatapere
# Processing Record 41 of Set 1 | villamontes
# Processing Record 42 of Set 1 | salalah
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | paracuru
# Processing Record 45 of Set 1 | gornopravdinsk
# Processing Record 46 of Set 1 | tadine
# Processing Record 47 of Set 1 | namibe
# Processing Record 48 of Set 1 | havre-saint-pierre
# Processing Record 49 of Set 1 | faya
# Processing Record 50 of Set 1 | khasan
# Processing Record 1 of Set 2 | san policarpo
# Processing Record 2 of Set 2 | salekhard
# Processing Record 3 of Set 2 | tsumeb
# Processing Record 4 of Set 2 | greenfield
# Processing Record 5 of Set 2 | surab
# Processing Record 6 of Set 2 | sinnamary
# Processing Record 7 of Set 2 | melekhovskaya
# City not found. Skipping...
# Processing Record 8 of Set 2 | ponta do sol
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | tangkak
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | pinyug
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | lebu
# Processing Record 16 of Set 2 | tezu
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | kaitangata
# Processing Record 19 of Set 2 | lagoa
# Processing Record 20 of Set 2 | benguela
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | roald
# Processing Record 23 of Set 2 | upernavik
# Processing Record 24 of Set 2 | alofi
# Processing Record 25 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 2 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | mar del plata
# Processing Record 30 of Set 2 | nerchinsk
# Processing Record 31 of Set 2 | bethel
# Processing Record 32 of Set 2 | igarka
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | calama
# Processing Record 35 of Set 2 | mareeba
# Processing Record 36 of Set 2 | muromtsevo
# Processing Record 37 of Set 2 | kununurra
# Processing Record 38 of Set 2 | mahibadhoo
# Processing Record 39 of Set 2 | cayenne
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | thompson
# Processing Record 42 of Set 2 | tuktoyaktuk
# Processing Record 43 of Set 2 | ilulissat
# Processing Record 44 of Set 2 | norman wells
# Processing Record 45 of Set 2 | kurchum
# Processing Record 46 of Set 2 | hami
# Processing Record 47 of Set 2 | huangchuan
# Processing Record 48 of Set 2 | port elizabeth
# Processing Record 49 of Set 2 | bonfim
# Processing Record 50 of Set 2 | pancesti
# Processing Record 1 of Set 3 | el alto
# Processing Record 2 of Set 3 | new norfolk
# Processing Record 3 of Set 3 | stanovoye
# Processing Record 4 of Set 3 | port-cartier
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | maningrida
# Processing Record 7 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 3 | saskylakh
# Processing Record 9 of Set 3 | hay river
# Processing Record 10 of Set 3 | tasiilaq
# Processing Record 11 of Set 3 | sai buri
# Processing Record 12 of Set 3 | east london
# Processing Record 13 of Set 3 | kapaa
# Processing Record 14 of Set 3 | georgetown
# Processing Record 15 of Set 3 | qaanaaq
# Processing Record 16 of Set 3 | sorland
# Processing Record 17 of Set 3 | chuy
# Processing Record 18 of Set 3 | saint-georges
# Processing Record 19 of Set 3 | maniitsoq
# Processing Record 20 of Set 3 | codrington
# Processing Record 21 of Set 3 | najran
# Processing Record 22 of Set 3 | skelleftea
# Processing Record 23 of Set 3 | kavieng
# Processing Record 24 of Set 3 | hermanus
# Processing Record 25 of Set 3 | srednekolymsk
# Processing Record 26 of Set 3 | spirit river
# Processing Record 27 of Set 3 | sitka
# Processing Record 28 of Set 3 | balabac
# Processing Record 29 of Set 3 | millbrook
# Processing Record 30 of Set 3 | umm lajj
# Processing Record 31 of Set 3 | didao
# Processing Record 32 of Set 3 | paamiut
# Processing Record 33 of Set 3 | fortuna
# Processing Record 34 of Set 3 | tura
# Processing Record 35 of Set 3 | aklavik
# Processing Record 36 of Set 3 | kilindoni
# Processing Record 37 of Set 3 | marzuq
# Processing Record 38 of Set 3 | vardo
# Processing Record 39 of Set 3 | boa vista
# Processing Record 40 of Set 3 | nemuro
# Processing Record 41 of Set 3 | port augusta
# Processing Record 42 of Set 3 | cabo san lucas
# Processing Record 43 of Set 3 | vila franca do campo
# Processing Record 44 of Set 3 | nishihara
# Processing Record 45 of Set 3 | mumbwa
# Processing Record 46 of Set 3 | tiarei
# Processing Record 47 of Set 3 | richards bay
# Processing Record 48 of Set 3 | nuuk
# Processing Record 49 of Set 3 | nome
# Processing Record 50 of Set 3 | coahuayana
# Processing Record 1 of Set 4 | pleshanovo
# Processing Record 2 of Set 4 | victoria
# Processing Record 3 of Set 4 | chokurdakh
# Processing Record 4 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 4 | clyde river
# Processing Record 6 of Set 4 | clyde
# Processing Record 7 of Set 4 | pemangkat
# Processing Record 8 of Set 4 | mackay
# Processing Record 9 of Set 4 | salta
# Processing Record 10 of Set 4 | taoudenni
# Processing Record 11 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 4 | lazaro cardenas
# Processing Record 13 of Set 4 | trelew
# Processing Record 14 of Set 4 | kaka
# Processing Record 15 of Set 4 | wanning
# Processing Record 16 of Set 4 | price
# Processing Record 17 of Set 4 | sibolga
# Processing Record 18 of Set 4 | narsaq
# Processing Record 19 of Set 4 | deputatskiy
# Processing Record 20 of Set 4 | port-gentil
# Processing Record 21 of Set 4 | kampene
# Processing Record 22 of Set 4 | butaritari
# Processing Record 23 of Set 4 | asosa
# Processing Record 24 of Set 4 | satun
# Processing Record 25 of Set 4 | khatanga
# Processing Record 26 of Set 4 | rocky mountain house
# Processing Record 27 of Set 4 | sokolac
# Processing Record 28 of Set 4 | naze
# Processing Record 29 of Set 4 | yantal
# Processing Record 30 of Set 4 | ostrovnoy
# Processing Record 31 of Set 4 | korla
# Processing Record 32 of Set 4 | metro
# Processing Record 33 of Set 4 | walvis bay
# Processing Record 34 of Set 4 | meulaboh
# Processing Record 35 of Set 4 | parana
# Processing Record 36 of Set 4 | cabra
# Processing Record 37 of Set 4 | avarua
# Processing Record 38 of Set 4 | sept-iles
# Processing Record 39 of Set 4 | xichang
# Processing Record 40 of Set 4 | koslan
# Processing Record 41 of Set 4 | labuhan
# Processing Record 42 of Set 4 | pevek
# Processing Record 43 of Set 4 | the pas
# Processing Record 44 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 4 | abalak
# Processing Record 46 of Set 4 | jyvaskyla
# Processing Record 47 of Set 4 | palmer
# Processing Record 48 of Set 4 | dikson
# Processing Record 49 of Set 4 | cape town
# Processing Record 50 of Set 4 | warrnambool
# Processing Record 1 of Set 5 | maceio
# Processing Record 2 of Set 5 | bambous virieux
# Processing Record 3 of Set 5 | thaton
# Processing Record 4 of Set 5 | honningsvag
# Processing Record 5 of Set 5 | roma
# Processing Record 6 of Set 5 | castilho
# Processing Record 7 of Set 5 | yulara
# Processing Record 8 of Set 5 | camacha
# Processing Record 9 of Set 5 | yerbogachen
# Processing Record 10 of Set 5 | fethiye
# Processing Record 11 of Set 5 | faanui
# Processing Record 12 of Set 5 | klaksvik
# Processing Record 13 of Set 5 | henties bay
# Processing Record 14 of Set 5 | kieta
# Processing Record 15 of Set 5 | dinar
# Processing Record 16 of Set 5 | teahupoo
# Processing Record 17 of Set 5 | hithadhoo
# Processing Record 18 of Set 5 | shihezi
# Processing Record 19 of Set 5 | ghorawal
# Processing Record 20 of Set 5 | katsuura
# Processing Record 21 of Set 5 | saldanha
# Processing Record 22 of Set 5 | marsh harbour
# Processing Record 23 of Set 5 | atar
# Processing Record 24 of Set 5 | lingao
# Processing Record 25 of Set 5 | leningradskiy
# Processing Record 26 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 5 | lata
# Processing Record 28 of Set 5 | manggar
# Processing Record 29 of Set 5 | beyla
# Processing Record 30 of Set 5 | masterton
# Processing Record 31 of Set 5 | novorzhev
# Processing Record 32 of Set 5 | concordia
# Processing Record 33 of Set 5 | kargil
# Processing Record 34 of Set 5 | vila do maio
# Processing Record 35 of Set 5 | mehamn
# Processing Record 36 of Set 5 | noumea
# Processing Record 37 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 5 | chastyye
# Processing Record 39 of Set 5 | nhulunbuy
# Processing Record 40 of Set 5 | magdalena
# Processing Record 41 of Set 5 | vuktyl
# Processing Record 42 of Set 5 | severo-kurilsk
# Processing Record 43 of Set 5 | zhanakorgan
# Processing Record 44 of Set 5 | petropavlovka
# Processing Record 45 of Set 5 | haines junction
# Processing Record 46 of Set 5 | barcelona
# Processing Record 47 of Set 5 | dong hoi
# Processing Record 48 of Set 5 | ipixuna
# Processing Record 49 of Set 5 | yellowknife
# Processing Record 50 of Set 5 | lamesa
# Processing Record 1 of Set 6 | comodoro rivadavia
# Processing Record 2 of Set 6 | praia da vitoria
# Processing Record 3 of Set 6 | onega
# Processing Record 4 of Set 6 | edson
# Processing Record 5 of Set 6 | tazovskiy
# Processing Record 6 of Set 6 | camp springs
# Processing Record 7 of Set 6 | imbituba
# Processing Record 8 of Set 6 | nikolskoye
# Processing Record 9 of Set 6 | airai
# Processing Record 10 of Set 6 | port blair
# Processing Record 11 of Set 6 | bengkulu
# Processing Record 12 of Set 6 | tarko-sale
# Processing Record 13 of Set 6 | barkhan
# Processing Record 14 of Set 6 | hofn
# Processing Record 15 of Set 6 | muros
# Processing Record 16 of Set 6 | manuk mangkaw
# Processing Record 17 of Set 6 | kribi
# Processing Record 18 of Set 6 | talaya
# Processing Record 19 of Set 6 | carutapera
# Processing Record 20 of Set 6 | bikaner
# Processing Record 21 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 22 of Set 6 | derventa
# Processing Record 23 of Set 6 | zhuozhou
# City not found. Skipping...
# Processing Record 24 of Set 6 | bicas
# Processing Record 25 of Set 6 | orlik
# Processing Record 26 of Set 6 | sistranda
# Processing Record 27 of Set 6 | nguru
# Processing Record 28 of Set 6 | the valley
# Processing Record 29 of Set 6 | la asuncion
# Processing Record 30 of Set 6 | chimbote
# Processing Record 31 of Set 6 | komsomolskiy
# Processing Record 32 of Set 6 | umm kaddadah
# Processing Record 33 of Set 6 | santa luzia
# Processing Record 34 of Set 6 | fare
# Processing Record 35 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 6 | akyab
# Processing Record 37 of Set 6 | biltine
# Processing Record 38 of Set 6 | medicine hat
# Processing Record 39 of Set 6 | santo tomas
# Processing Record 40 of Set 6 | luderitz
# Processing Record 41 of Set 6 | erenhot
# Processing Record 42 of Set 6 | iskateley
# Processing Record 43 of Set 6 | te anau
# Processing Record 44 of Set 6 | key largo
# Processing Record 45 of Set 6 | dubbo
# Processing Record 46 of Set 6 | ambilobe
# Processing Record 47 of Set 6 | samoded
# Processing Record 48 of Set 6 | aykhal
# Processing Record 49 of Set 6 | uglegorsk
# Processing Record 50 of Set 6 | fairbanks
# Processing Record 1 of Set 7 | pochutla
# Processing Record 2 of Set 7 | laguna
# Processing Record 3 of Set 7 | san patricio
# Processing Record 4 of Set 7 | taywarah
# Processing Record 5 of Set 7 | lukovetskiy
# Processing Record 6 of Set 7 | strezhevoy
# Processing Record 7 of Set 7 | tornio
# Processing Record 8 of Set 7 | geraldton
# Processing Record 9 of Set 7 | coihaique
# Processing Record 10 of Set 7 | college
# Processing Record 11 of Set 7 | rudnogorsk
# Processing Record 12 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 7 | kikwit
# Processing Record 14 of Set 7 | leshukonskoye
# Processing Record 15 of Set 7 | yarada
# Processing Record 16 of Set 7 | vestmannaeyjar
# Processing Record 17 of Set 7 | ancud
# Processing Record 18 of Set 7 | palana
# Processing Record 19 of Set 7 | nara
# Processing Record 20 of Set 7 | seoul
# Processing Record 21 of Set 7 | shubarkuduk
# Processing Record 22 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 7 | reconquista
# Processing Record 24 of Set 7 | fuerte olimpo
# Processing Record 25 of Set 7 | bardiyah
# Processing Record 26 of Set 7 | sioux lookout
# Processing Record 27 of Set 7 | gimli
# Processing Record 28 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 7 | adrar
# Processing Record 30 of Set 7 | pacific grove
# Processing Record 31 of Set 7 | illela
# Processing Record 32 of Set 7 | puerto leguizamo
# Processing Record 33 of Set 7 | pisco
# Processing Record 34 of Set 7 | ngunguru
# Processing Record 35 of Set 7 | khani
# Processing Record 36 of Set 7 | sevsk
# Processing Record 37 of Set 7 | aleksandrovka
# Processing Record 38 of Set 7 | okhotsk
# Processing Record 39 of Set 7 | verkhnevilyuysk
# Processing Record 40 of Set 7 | mount gambier
# Processing Record 41 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 7 | cockburn town
# Processing Record 43 of Set 7 | katha
# City not found. Skipping...
# Processing Record 44 of Set 7 | dudinka
# Processing Record 45 of Set 7 | poum
# Processing Record 46 of Set 7 | joshimath
# Processing Record 47 of Set 7 | karlovac
# Processing Record 48 of Set 7 | santa rosa
# Processing Record 49 of Set 7 | moba
# Processing Record 50 of Set 7 | brae
# Processing Record 1 of Set 8 | kuytun
# Processing Record 2 of Set 8 | lavrentiya
# Processing Record 3 of Set 8 | fort saint james
# Processing Record 4 of Set 8 | north platte
# Processing Record 5 of Set 8 | coquimbo
# Processing Record 6 of Set 8 | uk
# City not found. Skipping...
# Processing Record 7 of Set 8 | port hardy
# Processing Record 8 of Set 8 | asau
# Processing Record 9 of Set 8 | bowen
# Processing Record 10 of Set 8 | hatillo
# Processing Record 11 of Set 8 | morant bay
# Processing Record 12 of Set 8 | gander
# Processing Record 13 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 14 of Set 8 | angoche
# Processing Record 15 of Set 8 | duluth
# Processing Record 16 of Set 8 | mahajanga
# Processing Record 17 of Set 8 | fort nelson
# Processing Record 18 of Set 8 | great bend
# Processing Record 19 of Set 8 | bubaque
# Processing Record 20 of Set 8 | rawah
# Processing Record 21 of Set 8 | talesh
# City not found. Skipping...
# Processing Record 22 of Set 8 | alpena
# Processing Record 23 of Set 8 | tori
# Processing Record 24 of Set 8 | nefteyugansk
# Processing Record 25 of Set 8 | goderich
# Processing Record 26 of Set 8 | vanimo
# Processing Record 27 of Set 8 | kruisfontein
# Processing Record 28 of Set 8 | sao joao da barra
# Processing Record 29 of Set 8 | vagay
# Processing Record 30 of Set 8 | bapatla
# Processing Record 31 of Set 8 | luba
# Processing Record 32 of Set 8 | nizhnyaya tavda
# Processing Record 33 of Set 8 | lockport
# Processing Record 34 of Set 8 | soyo
# Processing Record 35 of Set 8 | luganville
# Processing Record 36 of Set 8 | tarauaca
# Processing Record 37 of Set 8 | esperance
# Processing Record 38 of Set 8 | mersing
# Processing Record 39 of Set 8 | winsum
# Processing Record 40 of Set 8 | saint george
# Processing Record 41 of Set 8 | merauke
# Processing Record 42 of Set 8 | quatre cocos
# Processing Record 43 of Set 8 | talnakh
# Processing Record 44 of Set 8 | mitsamiouli
# Processing Record 45 of Set 8 | husavik
# Processing Record 46 of Set 8 | zemio
# Processing Record 47 of Set 8 | iqaluit
# Processing Record 48 of Set 8 | nizhnedevitsk
# Processing Record 49 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 8 | lianzhou
# Processing Record 1 of Set 9 | qazax
# Processing Record 2 of Set 9 | krasnyy profintern
# Processing Record 3 of Set 9 | setaka
# Processing Record 4 of Set 9 | milkovo
# Processing Record 5 of Set 9 | bandarbeyla
# Processing Record 6 of Set 9 | port lincoln
# Processing Record 7 of Set 9 | sur
# Processing Record 8 of Set 9 | havoysund
# Processing Record 9 of Set 9 | turkmenabat
# Processing Record 10 of Set 9 | tumpat
# Processing Record 11 of Set 9 | griffith
# Processing Record 12 of Set 9 | honiara
# Processing Record 13 of Set 9 | kahului
# Processing Record 14 of Set 9 | mwinilunga
# Processing Record 15 of Set 9 | la primavera
# Processing Record 16 of Set 9 | san cristobal
# Processing Record 17 of Set 9 | margate
# Processing Record 18 of Set 9 | mandera
# Processing Record 19 of Set 9 | hervey bay
# Processing Record 20 of Set 9 | krasnoselkup
# Processing Record 21 of Set 9 | touros
# Processing Record 22 of Set 9 | waingapu
# Processing Record 23 of Set 9 | cloquet
# Processing Record 24 of Set 9 | grindavik
# Processing Record 25 of Set 9 | bathsheba
# Processing Record 26 of Set 9 | sisimiut
# Processing Record 27 of Set 9 | tateyama
# Processing Record 28 of Set 9 | baghdad
# Processing Record 29 of Set 9 | rafaela
# Processing Record 30 of Set 9 | nortelandia
# Processing Record 31 of Set 9 | ballina
# Processing Record 32 of Set 9 | padang
# Processing Record 33 of Set 9 | vila velha
# Processing Record 34 of Set 9 | jamtara
# Processing Record 35 of Set 9 | akhmim
# Processing Record 36 of Set 9 | ardesen
# Processing Record 37 of Set 9 | yanchukan
# City not found. Skipping...
# Processing Record 38 of Set 9 | tilichiki
# Processing Record 39 of Set 9 | asyut
# Processing Record 40 of Set 9 | fredericksburg
# Processing Record 41 of Set 9 | sindor
# Processing Record 42 of Set 9 | sangar
# Processing Record 43 of Set 9 | broken hill
# Processing Record 44 of Set 9 | abha
# Processing Record 45 of Set 9 | ust-ilimsk
# Processing Record 46 of Set 9 | ixtapa
# Processing Record 47 of Set 9 | hanna
# Processing Record 48 of Set 9 | aswan
# Processing Record 49 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 1 of Set 10 | nattarasankottai
# Processing Record 2 of Set 10 | udaipur
# Processing Record 3 of Set 10 | louros
# Processing Record 4 of Set 10 | cukai
# Processing Record 5 of Set 10 | kodino
# Processing Record 6 of Set 10 | iquitos
# Processing Record 7 of Set 10 | verkhnyaya inta
# Processing Record 8 of Set 10 | longyearbyen
# Processing Record 9 of Set 10 | guerrero negro
# Processing Record 10 of Set 10 | zatoka
# Processing Record 11 of Set 10 | barcelos
# Processing Record 12 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 10 | tra vinh
# Processing Record 14 of Set 10 | lyubokhna
# Processing Record 15 of Set 10 | caravelas
# Processing Record 16 of Set 10 | vysoke myto
# Processing Record 17 of Set 10 | kiunga
# Processing Record 18 of Set 10 | penzance
# Processing Record 19 of Set 10 | mount isa
# Processing Record 20 of Set 10 | novoilinsk
# Processing Record 21 of Set 10 | puerto escondido
# Processing Record 22 of Set 10 | doembang nangbuat
# Processing Record 23 of Set 10 | tarata
# Processing Record 24 of Set 10 | bondo
# Processing Record 25 of Set 10 | cidreira
# Processing Record 26 of Set 10 | filingue
# Processing Record 27 of Set 10 | beloha
# Processing Record 28 of Set 10 | cap malheureux
# Processing Record 29 of Set 10 | balkhash
# Processing Record 30 of Set 10 | harrismith
# Processing Record 31 of Set 10 | abu zabad
# Processing Record 32 of Set 10 | iwanai
# Processing Record 33 of Set 10 | amapa
# Processing Record 34 of Set 10 | sao felix do xingu
# Processing Record 35 of Set 10 | yaan
# Processing Record 36 of Set 10 | myitkyina
# Processing Record 37 of Set 10 | mopipi
# Processing Record 38 of Set 10 | sibu
# Processing Record 39 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 10 | souillac
# Processing Record 41 of Set 10 | kasongo-lunda
# Processing Record 42 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 43 of Set 10 | elko
# Processing Record 44 of Set 10 | ornskoldsvik
# Processing Record 45 of Set 10 | along
# Processing Record 46 of Set 10 | turayf
# Processing Record 47 of Set 10 | zeya
# Processing Record 48 of Set 10 | grajau
# Processing Record 49 of Set 10 | san ramon
# Processing Record 50 of Set 10 | necochea
# Processing Record 1 of Set 11 | kozelsk
# Processing Record 2 of Set 11 | lamas
# Processing Record 3 of Set 11 | navalmoral de la mata
# Processing Record 4 of Set 11 | aksu
# Processing Record 5 of Set 11 | gat
# Processing Record 6 of Set 11 | hayato
# City not found. Skipping...
# Processing Record 7 of Set 11 | sao filipe
# Processing Record 8 of Set 11 | mahaicony
# City not found. Skipping...
# Processing Record 9 of Set 11 | frontera
# Processing Record 10 of Set 11 | nathdwara
# Processing Record 11 of Set 11 | verkhoyansk
# Processing Record 12 of Set 11 | bilibino
# Processing Record 13 of Set 11 | ledyard
# Processing Record 14 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 11 | port hawkesbury
# Processing Record 16 of Set 11 | cangzhou
# Processing Record 17 of Set 11 | los llanos de aridane
# Processing Record 18 of Set 11 | kushmurun
# Processing Record 19 of Set 11 | kintampo
# Processing Record 20 of Set 11 | dzhebariki-khaya
# Processing Record 21 of Set 11 | misratah
# Processing Record 22 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 11 | kattivakkam
# Processing Record 24 of Set 11 | terney
# Processing Record 25 of Set 11 | pokhara
# Processing Record 26 of Set 11 | bolshoye nagatkino
# Processing Record 27 of Set 11 | ulaangom
# Processing Record 28 of Set 11 | jacksonville
# Processing Record 29 of Set 11 | enshi
# Processing Record 30 of Set 11 | sabang
# Processing Record 31 of Set 11 | wyszkow
# Processing Record 32 of Set 11 | surat
# Processing Record 33 of Set 11 | togur
# Processing Record 34 of Set 11 | vavozh
# Processing Record 35 of Set 11 | arman
# Processing Record 36 of Set 11 | saint stephen
# Processing Record 37 of Set 11 | rincon de la victoria
# Processing Record 38 of Set 11 | kontagora
# Processing Record 39 of Set 11 | kibre mengist
# Processing Record 40 of Set 11 | ewa beach
# Processing Record 41 of Set 11 | san quintin
# Processing Record 42 of Set 11 | amazar
# Processing Record 43 of Set 11 | minab
# Processing Record 44 of Set 11 | damietta
# Processing Record 45 of Set 11 | mayor pablo lagerenza
# Processing Record 46 of Set 11 | gigmoto
# Processing Record 47 of Set 11 | madimba
# Processing Record 48 of Set 11 | pervomayskiy
# Processing Record 49 of Set 11 | harper
# Processing Record 50 of Set 11 | gladstone
# Processing Record 1 of Set 12 | odweyne
# Processing Record 2 of Set 12 | mitzic
# Processing Record 3 of Set 12 | presidencia roque saenz pena
# Processing Record 4 of Set 12 | setermoen
# Processing Record 5 of Set 12 | mao
# Processing Record 6 of Set 12 | rawson
# Processing Record 7 of Set 12 | pozo colorado
# Processing Record 8 of Set 12 | olafsvik
# Processing Record 9 of Set 12 | irbeyskoye
# Processing Record 10 of Set 12 | luau
# Processing Record 11 of Set 12 | oksovskiy
# Processing Record 12 of Set 12 | port hedland
# Processing Record 13 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 12 | port moresby
# Processing Record 15 of Set 12 | tarakan
# Processing Record 16 of Set 12 | ilawa
# Processing Record 17 of Set 12 | lunavada
# Processing Record 18 of Set 12 | yarmouth
# Processing Record 19 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 20 of Set 12 | roquetas de mar
# Processing Record 21 of Set 12 | vao
# Processing Record 22 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 23 of Set 12 | kavaratti
# Processing Record 24 of Set 12 | tallahassee
# Processing Record 25 of Set 12 | kenai
# Processing Record 26 of Set 12 | hope
# Processing Record 27 of Set 12 | erdenet
# Processing Record 28 of Set 12 | springbok
# Processing Record 29 of Set 12 | oranjemund
# Processing Record 30 of Set 12 | beyneu
# Processing Record 31 of Set 12 | saint-pierre
# Processing Record 32 of Set 12 | yeppoon
# Processing Record 33 of Set 12 | cariati
# Processing Record 34 of Set 12 | chokwe
# Processing Record 35 of Set 12 | itoman
# Processing Record 36 of Set 12 | acarau
# Processing Record 37 of Set 12 | lesnoy
# Processing Record 38 of Set 12 | pitimbu
# Processing Record 39 of Set 12 | tessalit
# Processing Record 40 of Set 12 | santa isabel do rio negro
# Processing Record 41 of Set 12 | ilinskiy
# Processing Record 42 of Set 12 | tautira
# Processing Record 43 of Set 12 | balloch
# Processing Record 44 of Set 12 | ojinaga
# Processing Record 45 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 47 of Set 12 | guadalupe y calvo
# Processing Record 48 of Set 12 | mabaruma
# Processing Record 49 of Set 12 | antofagasta
# Processing Record 50 of Set 12 | ivybridge
# Processing Record 1 of Set 13 | geresk
# City not found. Skipping...
# Processing Record 2 of Set 13 | altamira
# Processing Record 3 of Set 13 | skibbereen
# Processing Record 4 of Set 13 | kalengwa
# Processing Record 5 of Set 13 | aleksandrovskoye
# Processing Record 6 of Set 13 | el tocuyo
# Processing Record 7 of Set 13 | ati
# Processing Record 8 of Set 13 | saint-joseph
# Processing Record 9 of Set 13 | buraydah
# Processing Record 10 of Set 13 | falmouth
# Processing Record 11 of Set 13 | yumen
# Processing Record 12 of Set 13 | moerai
# Processing Record 13 of Set 13 | baijiantan
# Processing Record 14 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 13 | tambura
# Processing Record 16 of Set 13 | greystones
# Processing Record 17 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 18 of Set 13 | zonalnoye
# City not found. Skipping...
# Processing Record 19 of Set 13 | kapit
# Processing Record 20 of Set 13 | ginda
# Processing Record 21 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 13 | la rioja
# Processing Record 24 of Set 13 | kpandae
# Processing Record 25 of Set 13 | alta floresta
# Processing Record 26 of Set 13 | simbahan
# Processing Record 27 of Set 13 | zamora
# Processing Record 28 of Set 13 | huambo
# Processing Record 29 of Set 13 | barabinsk
# Processing Record 30 of Set 13 | rio grande
# Processing Record 31 of Set 13 | whyalla
# Processing Record 32 of Set 13 | mecca
# Processing Record 33 of Set 13 | hambantota
# Processing Record 34 of Set 13 | minsk
# Processing Record 35 of Set 13 | salym
# Processing Record 36 of Set 13 | maunabo
# Processing Record 37 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 13 | makakilo city
# Processing Record 39 of Set 13 | tala
# Processing Record 40 of Set 13 | zhigansk
# Processing Record 41 of Set 13 | kindu
# Processing Record 42 of Set 13 | amiens
# Processing Record 43 of Set 13 | banjar
# Processing Record 44 of Set 13 | saint anthony
# Processing Record 45 of Set 13 | zhireken
# Processing Record 46 of Set 13 | jalu
# Processing Record 47 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 48 of Set 13 | atagay
# Processing Record 49 of Set 13 | tamandare
# Processing Record 50 of Set 13 | roura
# Processing Record 1 of Set 14 | nata
# Processing Record 2 of Set 14 | severobaykalsk
# Processing Record 3 of Set 14 | guanica
# Processing Record 4 of Set 14 | traverse city
# Processing Record 5 of Set 14 | suntar
# Processing Record 6 of Set 14 | akdepe
# Processing Record 7 of Set 14 | labytnangi
# Processing Record 8 of Set 14 | kailua
# Processing Record 9 of Set 14 | punto fijo
# Processing Record 10 of Set 14 | goure
# Processing Record 11 of Set 14 | pa sang
# Processing Record 12 of Set 14 | general roca
# Processing Record 13 of Set 14 | mosquera
# Processing Record 14 of Set 14 | gamba
# Processing Record 15 of Set 14 | agvali
# Processing Record 16 of Set 14 | huarmey
# Processing Record 17 of Set 14 | polunochnoye
# Processing Record 18 of Set 14 | safaqis
# City not found. Skipping...
# Processing Record 19 of Set 14 | nouadhibou
# Processing Record 20 of Set 14 | krasnomayskiy
# Processing Record 21 of Set 14 | beringovskiy
# Processing Record 22 of Set 14 | tres arroyos
# Processing Record 23 of Set 14 | kargat
# Processing Record 24 of Set 14 | bundaberg
# Processing Record 25 of Set 14 | samsun
# Processing Record 26 of Set 14 | uray
# Processing Record 27 of Set 14 | kyzyl
# Processing Record 28 of Set 14 | ekhabi
# Processing Record 29 of Set 14 | datong
# Processing Record 30 of Set 14 | fort frances
# Processing Record 31 of Set 14 | chara
# Processing Record 32 of Set 14 | amahai
# Processing Record 33 of Set 14 | pangnirtung
# Processing Record 34 of Set 14 | kholodnyy
# Processing Record 35 of Set 14 | bac lieu
# Processing Record 36 of Set 14 | kashi
# Processing Record 37 of Set 14 | leh
# Processing Record 38 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 14 | lufilufi
# Processing Record 40 of Set 14 | juneau
# Processing Record 41 of Set 14 | evensk
# Processing Record 42 of Set 14 | grand gaube
# Processing Record 43 of Set 14 | salvador
# Processing Record 44 of Set 14 | boshkengash
# Processing Record 45 of Set 14 | proletariy
# Processing Record 46 of Set 14 | dolores
# Processing Record 47 of Set 14 | birsk
# Processing Record 48 of Set 14 | mossoro
# Processing Record 49 of Set 14 | aktash
# Processing Record 50 of Set 14 | bone
# Processing Record 1 of Set 15 | taksimo
# Processing Record 2 of Set 15 | tomatlan
# Processing Record 3 of Set 15 | kemijarvi
# Processing Record 4 of Set 15 | kijang
# Processing Record 5 of Set 15 | northam
# Processing Record 6 of Set 15 | de-kastri
# Processing Record 7 of Set 15 | rosarito
# Processing Record 8 of Set 15 | nigde
# Processing Record 9 of Set 15 | tahe
# Processing Record 10 of Set 15 | cabedelo
# Processing Record 11 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 13 of Set 15 | olinda
# Processing Record 14 of Set 15 | natchitoches
# Processing Record 15 of Set 15 | tevaitoa
# Processing Record 16 of Set 15 | ende
# Processing Record 17 of Set 15 | vigrestad
# Processing Record 18 of Set 15 | robertsport
# Processing Record 19 of Set 15 | khokhlovo
# Processing Record 20 of Set 15 | caraballeda
# Processing Record 21 of Set 15 | timizart
# Processing Record 22 of Set 15 | chase
# Processing Record 23 of Set 15 | pundaguitan
# Processing Record 24 of Set 15 | tiznit
# Processing Record 25 of Set 15 | vlissingen
# Processing Record 26 of Set 15 | fomboni
# Processing Record 27 of Set 15 | awash
# Processing Record 28 of Set 15 | mantua
# Processing Record 29 of Set 15 | nikolayevka
# Processing Record 30 of Set 15 | micheweni
# Processing Record 31 of Set 15 | aborlan
# Processing Record 32 of Set 15 | pontianak
# Processing Record 33 of Set 15 | dunedin
# Processing Record 34 of Set 15 | anadyr
# Processing Record 35 of Set 15 | jackson
# Processing Record 36 of Set 15 | guinguineo
# Processing Record 37 of Set 15 | kamenka
# Processing Record 38 of Set 15 | san jeronimo
# Processing Record 39 of Set 15 | bud
# Processing Record 40 of Set 15 | kualakapuas
# Processing Record 41 of Set 15 | turukhansk
# Processing Record 42 of Set 15 | brownsville
# Processing Record 43 of Set 15 | lubumbashi
# Processing Record 44 of Set 15 | lasa
# Processing Record 45 of Set 15 | punta alta
# Processing Record 46 of Set 15 | floro
# Processing Record 47 of Set 15 | kiama
# Processing Record 48 of Set 15 | lentekhi
# Processing Record 49 of Set 15 | hovd
# Processing Record 50 of Set 15 | beira
# Processing Record 1 of Set 16 | urdzhar
# City not found. Skipping...
# Processing Record 2 of Set 16 | pangai
# Processing Record 3 of Set 16 | zig
# Processing Record 4 of Set 16 | pascagoula
# Processing Record 5 of Set 16 | samarai
# Processing Record 6 of Set 16 | hualmay
# Processing Record 7 of Set 16 | xai-xai
# Processing Record 8 of Set 16 | tanga
# Processing Record 9 of Set 16 | viedma
# Processing Record 10 of Set 16 | rocha
# Processing Record 11 of Set 16 | isla mujeres
# Processing Record 12 of Set 16 | ulladulla
# Processing Record 13 of Set 16 | gondanglegi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 709

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Ribeira Grande  38.5167  -28.7000     64.80        94          75
# 1       Jamestown  42.0970  -79.2353     28.02        49          75
# 2          Castro -24.7911  -50.0119     69.84        63          15
# 3       Mahebourg -20.4081   57.7000     70.09        83          20
# 4     Provideniya  64.3833 -173.3000     25.56        84         100
# 5  Barra Do Corda  -5.5000  -45.2500     73.26        96         100
# 6           Bluff -46.6000  168.3333     58.80        83          64
# 7          Shingu  33.7333  135.9833     62.47        90          97
# 8         Rikitea -23.1203 -134.9692     71.08        67          93
# 9  Saint-Philippe -21.3585   55.7679     71.19        79          24
#
#    Wind Speed Country      Current Description
# 0       13.00      PT  light intensity drizzle
# 1       13.80      US            broken clouds
# 2        4.70      BR               few clouds
# 3        3.44      MU               few clouds
# 4        6.11      RU          overcast clouds
# 5        4.32      BR            moderate rain
# 6        8.95      NZ            broken clouds
# 7       17.87      JP               light rain
# 8        9.28      PF          overcast clouds
# 9        8.72      RE               few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order=["City", "Country", "Lat", "Lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Ribeira Grande      PT  38.5167  -28.7000     64.80        94          75
# 1       Jamestown      US  42.0970  -79.2353     28.02        49          75
# 2          Castro      BR -24.7911  -50.0119     69.84        63          15
# 3       Mahebourg      MU -20.4081   57.7000     70.09        83          20
# 4     Provideniya      RU  64.3833 -173.3000     25.56        84         100
#
#    Wind Speed      Current Description
# 0       13.00  light intensity drizzle
# 1       13.80            broken clouds
# 2        4.70               few clouds
# 3        3.44               few clouds
# 4        6.11          overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
